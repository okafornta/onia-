# %% [markdown]
# # COMPANY RECEIPT

# %%
p1_name, p1_price = "Rice", 12000
p2_name, p2_price = "Beans", 20000
p3_name, p3_price = "Tomatoes", 7000
p4_name, p4_price = "Maggie", 2000
p5_name, p5_price = "Onions", 6000
p6_name, p6_price = "Cray-fish", 10000
p7_name, p7_price = "Pepper", 1500
p8_name, p8_price = "Oil", 9000
p9_name, p9_price = "Omo", 2500
p10_name, p10_price = "Onga", 500

# creating the company information 
company_name = "cosytee catering service"
company_address = "105 Amechi Road, Topland Awkunanaw"
company_country = "nigeria"
company_city = "Enugu"
company_postalcode = "400108"
company_phone = "08063728221"

# declare ending message 
message = "Thank you for petronizing us today"

# create a top border
print("*" * 60)

# displaying company information
print("\t\t{}".format(company_name.upper()))
print("\t\t{}".format(company_address))
print("\t\t{}".format(company_country.title()))
print("\t\t{}".format(company_city))
print("\t\t{}".format(company_postalcode))
print("\t\t{}".format(company_phone))

# create border between the line
print("=" * 60)

# displaying product information
print("\tProduct Name\tProduct Price\tQty\tTotal")

# create print statement for each product 
print("\t{}\t\t${}".format(p1_name.title(), p1_price))
print("\t{}\t\t${}".format(p2_name.title(), p2_price))
print("\t{}\t\t${}".format(p3_name.title(), p3_price))
print("\t{}\t\t${}".format(p4_name.title(), p4_price))
print("\t{}\t\t${}".format(p5_name.title(), p5_price))
print("\t{}\t\t${}".format(p6_name.title(), p6_price))
print("\t{}\t\t${}".format(p7_name.title(), p7_price))
print("\t{}\t\t${}".format(p8_name.title(), p8_price))
print("\t{}\t\t${}".format(p9_name.title(), p9_price))
print("\t{}\t\t${}".format(p10_name.title(), p10_price))

# print line between the sections
print("+" * 60)

print("\t\t\tTotal")
total = p1_price + p2_price + p3_price + p4_price + p5_price + p6_price + p7_price + p8_price + p9_price + p10_price
print("\t\t\t${}".format(total))
print("=" * 60)
print("\n\t{}\n".format(message))
print("*" * 60)
# Out:
# ************************************************************
# 		COSYTEE CATERING SERVICE
# 		105 Amechi Road, Topland Awkunanaw
# 		Nigeria
# 		Enugu
# 		400108
# 		08063728221
# ...
# 	Product Name	Product Price	Qty	Total
# 	Rice		$12000
# 	Beans		$20000
# 	Tomatoes		$7000
# 	Maggie		$2000
# 	Onions		$6000
# 	Cray-Fish		$10000
# 	Pepper		$1500
# 	Oil		$9000
# 	Omo		$2500
# 	Onga		$500
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 			Total
# 			$70500
# ...
#
# 	Thank you for petronizing us today
#
# ************************************************************

# %%
# create price list 
p1_name, p1_price = "book", 40.23
p2_name, p2_price = "monitor", 60
p3_name, p3_price = "mouse", 79.30

# create contact information and adresses 
company_name = "icantech"
company_address = "102 Ebony Paint ,Rd"
company_city = "Enugu"
company_country = "Nigeria"

# create top border 
print("*" * 50)

# displaying text
message = "Thanking for your support"

# display company information
print("\t\t\t{}".format(company_name.upper()))

print("\t\t\t{}".format(company_address))
print("\t\t\t{}".format(company_city))
print("\t\t\t{}".format(company_country))

# create line between section
print("=" * 50)

# displaying product product and price 
print("\tProduct Name\tProduct Price\tQty\tTotal")

# displaying list of items
print("\t{}\t\t${}".format(p1_name.title(), p1_price))
print("\t{}\t\t${}".format(p2_name.title(), p2_price))
print("\t{}\t\t${}".format(p3_name.title(), p3_price))

# display buttom line
print("=" * 50)
# adding total
print("\t\t\tTotal")

# adding ip the product price 
total = p1_price + p2_price + p3_price
print("\t\t\t${}".format(total))
print("*" * 50)

print("\n\t{}".format(message))
print("*" * 50)
# Out:
# **************************************************
# 			ICANTECH
# 			102 Ebony Paint ,Rd
# 			Enugu
# 			Nigeria
# ...
# 	Product Name	Product Price	Qty	Total
# 	Book		$40.23
# 	Monitor		$60
# 	Mouse		$79.3
# ...
# 			Total
# 			$179.52999999999997
# **************************************************
#
# 	Thanking for your support
# **************************************************
